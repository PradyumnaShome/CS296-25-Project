# %%
import pandas as pd
data = pd.read_csv("uiuc-students-by-curriculum-cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-7e6048753590> in <module>
#       1 import pandas as pd
# ----> 2 data = pd.read_csv("uiuc-students-by-curriculum-cleaned.csv")
#
# ~\Miniconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
colleges = data[]
for year in data['Fall'] :
    year_data = data.loc[data['Fall'] == year]
    print(year_data)
    csv_name = ''
# Out:
#    Fall  Total  Agricultural & Applied Econ  Agricultural Communications  \
# 0  1980  27591                          315                           79
#
#    Classics  Teaching of Biological Science  Teaching of French  \
# 0         9                               1                  15
#
#    Teaching of Latin  ENGR MECH  GEN AGRIC  ...  \
# 0                  2         34          1  ...
#
#    Strategic Brand Communication  Education Curriculum Uassign  \
# 0                              0                             0
#
#    Pre-Engineering  Computer Science & Economics  Computer Science and Music  \
# 0                0                             0                           0
#
#    Econometrics & Quant Econ  Germanic Studies  \
# 0                          0                 0
#
#    Computer Science&Crop Sciences  Lyric Theatre  \
# 0                               0              0
#
#    Medicine - Carle Illinois COM
# 0                              0
#
# ...
